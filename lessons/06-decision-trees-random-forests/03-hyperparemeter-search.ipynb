# %% [markdown]
# # Hyperparameter Search
#
# Whenever we build an ML model, we have a lot of choicess to make about hyperparameters. Sometimes we can rely on our intuition to guide us towards good choices, but one of the main benefits of ML models is that they find surprising results by "thinking" quite differently from the way most people think. Being primarally a statistical discipline, machine learning experts will often use validation data, a technique called "cross validation," and programatic methods to explore the possible combinations of hyperparameters and find ones that produce good models emperically.
#
# SKLearn provides two very helpful classes for executing hyperparameter search: GridSearchCV and RandomizedSearchCV.
#
# ### Crosss Validation:
#
# There are many kinds of cross validation, see https://scikit-learn.org/stable/modules/cross_validation.html for more details. In this lab we're going to use something called k-fold cross validation (because it is the default for SKLearn's hyperparameter search methods) but we strongly suggest experimenting with methods, especially "stratified k-fold" cross validation, which can also be easily applied to hyperparameter search using SKLearn.
#
# K-Fold cross validation separates your training dataset into K different training and validation sets, ensuring that each datapoint occurs in exactly one of the validation sets, and therefore appears in K-1 training sets. Take a look at this picture from the SKlearn docs:
#
# ![K-Fold Cross Validation Visualized.](https://scikit-learn.org/stable/_images/sphx_glr_plot_cv_indices_0041.png)
#
# Cross validation is more expensive computationally than having a single training/validation split, but it provides a more robust estimate of our model's performance and generalization. Generally, when we have found the hyperparameter set we like via cross validation, we retrain the model one more time with ALL the training data before evaluating our results on a held-out test set.
#
# Stratified K-Fold cross validation is like K-Fold, but it takes extra steps to ensure that for all K validation sets, an equal number of datapoints selected from each of the classes in our classifiation problem. See this image from the sklearn docs again:
#
# ![Stratified K-Fold Cross Validation Visualized](https://scikit-learn.org/stable/_images/sphx_glr_plot_cv_indices_0071.png)
#
# Typically "stratified" tactics are applied to classification problems, but there are similar tactics for regression problems. See this article for more information about that: https://scottclowe.com/2016-03-19-stratified-regression-partitions/
#
# ### Hyperparameter search
#
# In SK-Learn we can use a single class to combine the search process with cross validation, automatically finding the best hyperparameters according to our cross-validation scores along whatever metrics we specifiy (e.g. accuracy or r^2). In both cases, sk-learn maintains information about the performance of all the models it trains, and gives us mechanisms to get the best one found without retraining.
#
# The two tactics are:
#
# #### Grid Search
#
# We supply a set of values for each hyperparameter that we want to search acrosss. SK-learn computes all the possible combinations of our selections and performs cross-validation on for each combination.
#
# #### Randomized Search
#
# We supply a range of values for the hyperparameters we are interested in. SK-learn randomly selects values for each hyperparameter within our ranges and performs cross-validation. We specify how many times to perform this process.

# %%
# Lets do grid search cross validation on a Decision Tree:
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV


# Load the data
heart_dataset = pd.read_csv('../../datasets/uci-heart-disease/heart.csv')

# Split the data into input and labels
labels = heart_dataset['target']
input_data = heart_dataset.drop(columns=['target'])

# Note, we don't split the data. GridSearchCV will automatically apply 5-fold cross validation by default.

tuned_parameters = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 3, 5, 10, 20],
    'min_samples_split': [2, 4, 8, 16, 32],
    'max_leaf_nodes': [None, 10, 20, 40, 80]
}

# These two lines will result in every possible combo of the above paramters to be fit and scored
# which can take a LONG TIME with large datasets.
clf = DecisionTreeClassifier()
grid_tree = GridSearchCV(clf, tuned_parameters)
grid_tree.fit(input_data, labels) 

print("Best parameters set found on development set:")
print()
print(grid_tree.best_params_, grid_tree.best_score_)
print()
print("Grid scores on development set:")
print()
means = grid_tree.cv_results_['mean_test_score']
stds = grid_tree.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_tree.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32} 0.8150273224043716
#
# Grid scores on development set:
#
# 0.752 (+/-0.104) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.759 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.772 (+/-0.085) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.792 (+/-0.113) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.779 (+/-0.121) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.765 (+/-0.084) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.772 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.762 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.749 (+/-0.079) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.756 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.759 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.759 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.759 (+/-0.106) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.765 (+/-0.085) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.782 (+/-0.099) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.772 (+/-0.100) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.782 (+/-0.088) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.755 (+/-0.112) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.789 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.792 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.789 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.775 (+/-0.125) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.775 (+/-0.101) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.785 (+/-0.102) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.772 (+/-0.083) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.755 (+/-0.112) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.775 (+/-0.113) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.775 (+/-0.095) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.772 (+/-0.093) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.755 (+/-0.112) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.772 (+/-0.118) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.785 (+/-0.093) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.779 (+/-0.078) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.759 (+/-0.104) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.762 (+/-0.113) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.752 (+/-0.107) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.769 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.792 (+/-0.113) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.775 (+/-0.125) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.772 (+/-0.081) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.769 (+/-0.077) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.772 (+/-0.096) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.746 (+/-0.091) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.762 (+/-0.101) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.775 (+/-0.087) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.752 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.742 (+/-0.094) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.769 (+/-0.075) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.752 (+/-0.106) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.762 (+/-0.113) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.765 (+/-0.104) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.792 (+/-0.071) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.795 (+/-0.115) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.795 (+/-0.105) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.775 (+/-0.125) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.779 (+/-0.078) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.769 (+/-0.088) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.765 (+/-0.097) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.746 (+/-0.106) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.752 (+/-0.120) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.772 (+/-0.078) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.752 (+/-0.108) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.762 (+/-0.126) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.752 (+/-0.077) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.766 (+/-0.078) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.799 (+/-0.066) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.752 (+/-0.110) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.732 (+/-0.121) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.749 (+/-0.092) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.765 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.765 (+/-0.098) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.756 (+/-0.119) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.746 (+/-0.097) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.752 (+/-0.110) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.749 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.759 (+/-0.096) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.739 (+/-0.130) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.742 (+/-0.118) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.756 (+/-0.136) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.766 (+/-0.108) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.765 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.772 (+/-0.128) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.765 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.769 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.775 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.759 (+/-0.146) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.769 (+/-0.145) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.756 (+/-0.156) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.769 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.779 (+/-0.115) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.746 (+/-0.116) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.729 (+/-0.115) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.756 (+/-0.083) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.762 (+/-0.117) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.765 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.746 (+/-0.132) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.759 (+/-0.067) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.739 (+/-0.131) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.752 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.739 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.739 (+/-0.110) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.746 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 80, 'min_samples_split': 32}
# 0.749 (+/-0.125) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 2}
# 0.752 (+/-0.106) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 4}
# 0.756 (+/-0.083) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': None, 'min_samples_split': 32}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 2}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 4}
# 0.802 (+/-0.122) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 8}
# 0.788 (+/-0.120) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 10, 'min_samples_split': 32}
# 0.762 (+/-0.117) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 2}
# 0.765 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 4}
# 0.759 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 20, 'min_samples_split': 32}
# 0.749 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 2}
# 0.746 (+/-0.077) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 4}
# 0.746 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 40, 'min_samples_split': 32}
# 0.752 (+/-0.099) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 2}
# 0.749 (+/-0.093) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 4}
# 0.759 (+/-0.090) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 8}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 16}
# 0.815 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 80, 'min_samples_split': 32}

# %%
# We have to use scipy to provide the sampling distributions for our random search
from scipy.stats import randint as sp_randint

# Lists will be uniformly sampled.
# Distributions from scipy will follow the sampling distribution 
# (uniform in this case, but you could use any other provided distribution)
param_dist = {"max_depth": [None, 3, 5, 10, 20],
              "min_samples_split": sp_randint(2, 32),
              "max_leaf_nodes": sp_randint(2, 80),
              "criterion": ["gini", "entropy"]}

# Above, 250 combinations will be tried. The main benefit of randomized search
# is to reduce the search time but come up with similar results. So lets do
# just 100 iterations instead of 250 and see how similar 
clf = DecisionTreeClassifier()
n_iter_search = 100
random_search = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=n_iter_search)
random_search.fit(input_data, labels)

print("Best parameters set found on development set:")
print()
print(random_search.best_params_, random_search.best_score_)
print()
print("Scores on development set:")
print()
means = random_search.cv_results_['mean_test_score']
stds = random_search.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, random_search.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 49, 'min_samples_split': 29} 0.8183060109289617
#
# Scores on development set:
#
# 0.765 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 44, 'min_samples_split': 18}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 60, 'min_samples_split': 18}
# 0.792 (+/-0.106) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 49, 'min_samples_split': 20}
# 0.765 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 18, 'min_samples_split': 11}
# 0.798 (+/-0.070) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 45, 'min_samples_split': 29}
# 0.756 (+/-0.099) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 38, 'min_samples_split': 11}
# 0.808 (+/-0.096) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 22, 'min_samples_split': 30}
# 0.805 (+/-0.119) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 7, 'min_samples_split': 20}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 48, 'min_samples_split': 20}
# 0.795 (+/-0.113) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 29, 'min_samples_split': 22}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 72, 'min_samples_split': 25}
# 0.765 (+/-0.099) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 53, 'min_samples_split': 8}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 62, 'min_samples_split': 19}
# 0.795 (+/-0.113) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 44, 'min_samples_split': 24}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 40, 'min_samples_split': 13}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 72, 'min_samples_split': 18}
# 0.798 (+/-0.125) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 4, 'min_samples_split': 10}
# 0.795 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 37, 'min_samples_split': 19}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 46, 'min_samples_split': 15}
# 0.769 (+/-0.094) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 21, 'min_samples_split': 8}
# 0.805 (+/-0.063) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 39, 'min_samples_split': 27}
# 0.812 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 26, 'min_samples_split': 31}
# 0.788 (+/-0.100) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 73, 'min_samples_split': 19}
# 0.785 (+/-0.102) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 43, 'min_samples_split': 23}
# 0.736 (+/-0.119) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 76, 'min_samples_split': 4}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 8, 'min_samples_split': 16}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 24, 'min_samples_split': 31}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 30, 'min_samples_split': 14}
# 0.795 (+/-0.107) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 49, 'min_samples_split': 19}
# 0.812 (+/-0.094) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 49, 'min_samples_split': 31}
# 0.815 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 40, 'min_samples_split': 28}
# 0.775 (+/-0.097) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 30, 'min_samples_split': 13}
# 0.815 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 57, 'min_samples_split': 27}
# 0.805 (+/-0.066) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 38, 'min_samples_split': 4}
# 0.805 (+/-0.063) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 36, 'min_samples_split': 29}
# 0.739 (+/-0.108) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 44, 'min_samples_split': 4}
# 0.776 (+/-0.090) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 45, 'min_samples_split': 4}
# 0.785 (+/-0.102) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 44, 'min_samples_split': 24}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 27, 'min_samples_split': 17}
# 0.766 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 33, 'min_samples_split': 11}
# 0.789 (+/-0.060) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 18, 'min_samples_split': 30}
# 0.818 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 57, 'min_samples_split': 27}
# 0.766 (+/-0.095) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 57, 'min_samples_split': 14}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 53, 'min_samples_split': 22}
# 0.818 (+/-0.097) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 6, 'min_samples_split': 6}
# 0.812 (+/-0.094) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 61, 'min_samples_split': 31}
# 0.785 (+/-0.099) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 11, 'min_samples_split': 6}
# 0.775 (+/-0.092) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 79, 'min_samples_split': 18}
# 0.818 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 49, 'min_samples_split': 29}
# 0.805 (+/-0.063) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 54, 'min_samples_split': 28}
# 0.749 (+/-0.078) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 46, 'min_samples_split': 5}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 50, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 15, 'min_samples_split': 4}
# 0.736 (+/-0.085) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 70, 'min_samples_split': 6}
# 0.788 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 30, 'min_samples_split': 19}
# 0.792 (+/-0.106) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 37, 'min_samples_split': 21}
# 0.769 (+/-0.095) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 51, 'min_samples_split': 5}
# 0.815 (+/-0.098) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 52, 'min_samples_split': 28}
# 0.755 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 61, 'min_samples_split': 16}
# 0.818 (+/-0.102) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 18, 'min_samples_split': 29}
# 0.762 (+/-0.120) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 44, 'min_samples_split': 4}
# 0.772 (+/-0.101) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 74, 'min_samples_split': 2}
# 0.805 (+/-0.063) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 35, 'min_samples_split': 27}
# 0.755 (+/-0.112) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 45, 'min_samples_split': 17}
# 0.812 (+/-0.094) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 31, 'min_samples_split': 31}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 28, 'min_samples_split': 16}
# 0.772 (+/-0.104) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 14, 'min_samples_split': 14}
# 0.765 (+/-0.108) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 65, 'min_samples_split': 11}
# 0.798 (+/-0.067) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 60, 'min_samples_split': 28}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 15, 'min_samples_split': 7}
# 0.785 (+/-0.081) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 61, 'min_samples_split': 6}
# 0.798 (+/-0.070) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 31, 'min_samples_split': 27}
# 0.779 (+/-0.091) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 34, 'min_samples_split': 3}
# 0.818 (+/-0.102) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 36, 'min_samples_split': 29}
# 0.795 (+/-0.056) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 28, 'min_samples_split': 31}
# 0.766 (+/-0.093) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 61, 'min_samples_split': 13}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 13, 'min_samples_split': 15}
# 0.749 (+/-0.070) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 3, 'min_samples_split': 17}
# 0.795 (+/-0.113) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 64, 'min_samples_split': 22}
# 0.772 (+/-0.116) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 63, 'min_samples_split': 6}
# 0.772 (+/-0.084) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 64, 'min_samples_split': 2}
# 0.762 (+/-0.088) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 29, 'min_samples_split': 14}
# 0.815 (+/-0.084) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 5, 'min_samples_split': 14}
# 0.756 (+/-0.089) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 72, 'min_samples_split': 17}
# 0.802 (+/-0.050) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_split': 16}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 66, 'min_samples_split': 2}
# 0.769 (+/-0.092) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 49, 'min_samples_split': 10}
# 0.815 (+/-0.109) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 57, 'min_samples_split': 9}
# 0.762 (+/-0.101) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 35, 'min_samples_split': 16}
# 0.795 (+/-0.113) for {'criterion': 'entropy', 'max_depth': 20, 'max_leaf_nodes': 50, 'min_samples_split': 24}
# 0.788 (+/-0.095) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 34, 'min_samples_split': 20}
# 0.775 (+/-0.097) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 18, 'min_samples_split': 10}
# 0.782 (+/-0.124) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 47, 'min_samples_split': 6}
# 0.789 (+/-0.124) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 12, 'min_samples_split': 10}
# 0.798 (+/-0.070) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 68, 'min_samples_split': 28}
# 0.782 (+/-0.126) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 57, 'min_samples_split': 3}
# 0.762 (+/-0.088) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 79, 'min_samples_split': 14}
# 0.762 (+/-0.098) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 79, 'min_samples_split': 11}
# 0.795 (+/-0.077) for {'criterion': 'gini', 'max_depth': 20, 'max_leaf_nodes': 41, 'min_samples_split': 26}
# 0.769 (+/-0.077) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 70, 'min_samples_split': 9}
